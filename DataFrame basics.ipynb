# %%
import pandas as pd
general={
    'name':['abc','def','ghi','xyz'],
    'surname' : ['123','345','567','789'],
    'age': [1,2,3,400]
}

# %%
df=pd.DataFrame(general)
df
# Out:
#   name surname  age
# 0  abc     123    1
# 1  def     345    2
# 2  ghi     567    3
# 3  xyz     789  400

# %%
rows,columns=df.shape

# %%
df.head(2)
# Out:
#   name surname  age
# 0  abc     123    1
# 1  def     345    2

# %%
df.tail(1)
# Out:
#   name surname  age
# 3  xyz     789  400

# %%
df[1:4]
# Out:
#   name surname  age
# 1  def     345    2
# 2  ghi     567    3
# 3  xyz     789  400

# %%
df.columns
# Out:
# Index(['name', 'surname', 'age'], dtype='object')

# %%
df['name']
# Out:
# 0    abc
# 1    def
# 2    ghi
# 3    xyz
# Name: name, dtype: object

# %%
df['age'].max()
# Out:
# np.int64(400)

# %%
df.describe()
# Out:
#               age
# count    4.000000
# mean   101.500000
# std    199.001675
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%    102.250000
# max    400.000000

# %%
df[df.age > 2]
# Out:
#   name surname  age
# 2  ghi     567    3
# 3  xyz     789  400

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df=df.set_index('age') # return a new data frame as return type or use inplace=True inside set_index

# %%
help(df.loc())
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - An alignable boolean Series. The index of the key will be aligned before
#  |    masking.
# ...

# %% [markdown]
# We Can create dataframes using following ways-
# 1- From csv using->
# df=pd.read_csv('path')
#
# 2- From xlsx files using->
# df=pd.read_excel('path','sheet_name')
#
# 3- From dictionary using->
# df=pd.DataFrame(dic)
#
# 4- From tuple using->
# df=pd.DataFrame(tuple,columns=['name1','name2'])
